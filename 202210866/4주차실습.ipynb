# %% [markdown]
# <a href="https://colab.research.google.com/github/RunPhase/BigData_Visualization/blob/main/4%EC%A3%BC%EC%B0%A8%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #안녕하세요
# ##안녕하세요
# ###안녕하세요
# ####안녕하세요
# #####안녕하세요

# %% [markdown]
# **혼공분석**
#
# *혼공분석*
#
# ~~혼공분석~~
#
# > 혼공분석
#
# * 혼공분석
#
# - 혼공분석
#
#
#
#
# ![한빛미디어](data:image/png;base64,...)

# %% [markdown]
# $ y=x/tiles z$

# %%
print("Hello World")
# Out:
# Hello World

# %%
seconds_in_a_week = 24 * 60* 60 *7
seconds_in_a_week
# Out:
# 604800

# %%
seconds_in_a_week = 0
seconds_in_a_week
# Out:
# 0
